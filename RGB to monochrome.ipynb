# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('G:\protosem\class notes\python\images\crocodile.jpg')     
gray = rgb2gray(img)    
print(gray)
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()
# Out:
# [[  44.218   45.218   45.218 ...,   78.721   78.721   78.721]
#  [  46.218   46.218   46.218 ...,   78.721   78.721   78.721]
#  [  47.218   47.218   46.218 ...,   78.721   78.721   78.721]
#  ...,
#  [ 133.232  130.759  126.759 ...,  165.556  166.556  168.154]
#  [ 137.232  136.232  133.759 ...,  166.556  167.556  169.154]
#  [ 138.232  138.232  138.759 ...,  166.556  168.556  170.154]]
